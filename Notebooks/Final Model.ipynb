# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Ratings = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Book Recommendation System/Ratings_explicit.csv')
Ratings = Ratings[['User-ID','ISBN','Book-Rating']]
Ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276726  0155061224            5
# 1   276729  052165615X            3
# 2   276729  0521795028            6
# 3   276744  038550120X            7
# 4   276747  0060517794            9

# %%
Final_Dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Book Recommendation System/Final_Dataset.csv')
Final_Dataset.head()
# Out:
#    Unnamed: 0  User-ID   Age Country        ISBN  Book-Rating  Avg_Rating  \
# 0           0        8  33.0  canada  0002005018            5    7.666667
# 1           1    11676  28.0     NaN  0002005018            8    7.666667
# 2           2    67544  30.0  canada  0002005018            8    7.666667
# 3           3   116866  32.0   other  0002005018            9    7.666667
# 4           4   123629  33.0  canada  0002005018            9    7.666667
#
#    Total_No_Of_Users_Rated    Book-Title           Book-Author  \
# 0                        9  Clara Callan  Richard Bruce Wright
# 1                        9  Clara Callan  Richard Bruce Wright
# 2                        9  Clara Callan  Richard Bruce Wright
# 3                        9  Clara Callan  Richard Bruce Wright
# 4                        9  Clara Callan  Richard Bruce Wright
#
#    Year-Of-Publication              Publisher
# 0               2001.0  HarperFlamingo Canada
# 1               2001.0  HarperFlamingo Canada
# 2               2001.0  HarperFlamingo Canada
# 3               2001.0  HarperFlamingo Canada
# 4               2001.0  HarperFlamingo Canada

# %%
Books = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Book Recommendation System/Books.csv')
Books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
user_ratings_count = Final_Dataset.groupby('User-ID').size().reset_index(name='Rating_Count')

# Sort users by the number of ratings in descending order
top_users = user_ratings_count.sort_values(by='Rating_Count', ascending=False)
top_users
# Out:
#        User-ID  Rating_Count
# 2719     11676          6943
# 24101    98391          5691
# 46279   189835          1899
# 37648   153662          1845
# 5615     23902          1180
# ...        ...           ...
# 33245   135659             1
# 33246   135660             1
# 33250   135677             1
# 33252   135684             1
# 34045   138845             1
#
# [68091 rows x 2 columns]

# %%
top_users[top_users['Rating_Count']==11]
# Out:
#        User-ID  Rating_Count
# 10143    41123            11
# 42051   172216            11
# 20558    83842            11
# 55548   227859            11
# 34450   140423            11
# ...        ...           ...
# 1429      6115            11
# 49613   204044            11
# 5595     23835            11
# 43511   178056            11
# 30126   122958            11
#
# [478 rows x 2 columns]

# %%
# Ratings = Ratings.sample(50000)

# %%
Ratings.shape
# Out:
# (383842, 3)

# %%
# !pip install surprise
# Out:
# Collecting surprise
#   Downloading surprise-0.1-py2.py3-none-any.whl (1.8 kB)
# Collecting scikit-surprise (from surprise)
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.25.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp310-cp310-linux_x86_64.whl size=2357237 sha256=d1996b2dee5156b0095055d432bd296b60880847fce83101a8bb0e8f287c627d
#   Stored in directory: /root/.cache/pip/wheels/4b/3f/df/6acbf0a40397d9bf3ff97f582cc22fb9ce66adde75bc71fd54
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise, surprise
# Successfully installed scikit-surprise-1.1.4 surprise-0.1

# %%
from surprise import Reader, Dataset

# %%
reader = Reader(rating_scale=(0, 10))

# %%
from surprise.model_selection import cross_validate
from surprise import SVDpp, NMF
from sklearn.model_selection import train_test_split
from surprise import accuracy

# %%
train_df, test_df = train_test_split(Ratings, test_size=0.8)

# %%
data = Dataset.load_from_df(train_df[['User-ID','ISBN','Book-Rating']], reader)
trainset = data.build_full_trainset()
trainset

# %%
model_nmf = NMF()
model_nmf.fit(trainset)

# %%
model_svd = SVDpp()
model_svd.fit(trainset)

# %% [markdown]
# # **Make Recommendations**

# %%
def recomend_nmf(user_id, n=5):
  user_books = Ratings[Ratings['User-ID'] == user_id]['ISBN'].unique()
  all_books = Ratings['ISBN'].unique()
  books_to_predict = list(set(all_books) - set(user_books))

  user_books_str = [str(element) for element in user_books]
  a = (Final_Dataset[Final_Dataset['ISBN'].isin(user_books_str)]['Book-Title'].unique())



  user_book_pairs = [(user_id, book_id, 0) for book_id in books_to_predict]
  predictions_cf = model_nmf.test(user_book_pairs)

  top_n_recommendations = sorted(predictions_cf, key = lambda x: x.est, reverse = True)[:n]

  top_n_book_ids = [str(pred.iid) for pred in top_n_recommendations]

  top_n_book_ids_str = [str(element) for element in top_n_book_ids]
  b = (Final_Dataset[Final_Dataset['ISBN'].isin(top_n_book_ids_str)]['Book-Title'].unique())

  return a, b

# %%
def recomend_svd(user_id, n=5):
  user_books = Ratings[Ratings['User-ID'] == user_id]['ISBN'].unique()
  all_books = Ratings['ISBN'].unique()
  books_to_predict = list(set(all_books) - set(user_books))

  user_books_str = [str(element) for element in user_books]
  a = (Final_Dataset[Final_Dataset['ISBN'].isin(user_books_str)]['Book-Title'].unique())



  user_book_pairs = [(user_id, book_id, 0) for book_id in books_to_predict]
  predictions_cf = model_svd.test(user_book_pairs)

  top_n_recommendations = sorted(predictions_cf, key = lambda x: x.est, reverse = True)[:n]

  top_n_book_ids = [str(pred.iid) for pred in top_n_recommendations]

  top_n_book_ids_str = [str(element) for element in top_n_book_ids]
  b = (Final_Dataset[Final_Dataset['ISBN'].isin(top_n_book_ids_str)]['Book-Title'].unique())

  return a, b

# %%
user_id = 14

a, b = recomend_nmf(user_id)
# Out:
# array(['Mary-Kate &amp; Ashley Switching Goals (Mary-Kate and Ashley Starring in)',
#        "Tell Me This Isn't Happening", 'Flood : Mississippi 1927'],
#       dtype=object)

# %%
user_id = 276747

a, b = recomend_svd(user_id , 10)

print('\t************ Books Read By the User ************')
for i  in range(len(a)):
  print(f"{i+1}. {a[i]}")

print("\n\n")
print('\t************ Books Recommended to the User ************')
for i  in range(len(b)):
  print(f"{i+1}. {b[i]}")
# Out:
# 	************ Books Read By the User ************
# 1. Little Altars Everywhere
# 2. Birdsong: A Novel of Love and War
# 3. Waiting to Exhale
# 4. How to Deal With Difficult People
# 5. The Golden Rule of Schmoozing
#
#
#
# 	************ Books Recommended to the User ************
# 1. To Kill a Mockingbird
# 2. Harry Potter and the Prisoner of Azkaban (Book 3)
# 3. Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# 4. Harry Potter and the Order of the Phoenix (Book 5)
# 5. Dune (Remembering Tomorrow)
# 6. Harry Potter and the Goblet of Fire (Book 4)
# 7. The Other Boleyn Girl
# 8. The Two Towers (The Lord of the Rings, Part 2)
# 9. Harry Potter and the Chamber of Secrets Postcard Book
# 10. The Fellowship of the Ring (The Lord of the Rings, Part 1)

# %%
user_id = 276747

a, b = recomend_nmf(user_id , 30)

print('\t************ Books Read By the User ************')
for i  in range(len(a)):
  print(f"{i+1}. {a[i]}")

print("\n\n")
print('\t************ Books Recommended to the User ************')
for i  in range(len(b)):
  print(f"{i+1}. {b[i]}")
# Out:
# 	************ Books Read By the User ************
# 1. Little Altars Everywhere
# 2. Birdsong: A Novel of Love and War
# 3. Waiting to Exhale
# 4. How to Deal With Difficult People
# 5. The Golden Rule of Schmoozing
#
#
#
# 	************ Books Recommended to the User ************
# 1. Chopping Spree
# 2. America Writes: Learning English Through American Short Stories
# 3. The Prince of Egypt Collector's Edition Storybook
# 4. The Journey of Little Gandhi (Emergent Literatures)
# 5. A Pup in King Arthur's Court (Adventure of Wishbone)
# 6. Someday My Prince
# 7. Inside Vineyland
# 8. Sinful Truths   Passion (Harlequin Presents, 2344)
# 9. The Trouble with Tribbles
# 10. Death Among the Dons
# 11. Mystique
# 12. Listening to Prozac/a Psychiatrist Explores Antidepressant Drugs and the Remaking of the Self
# 13. Monster Makers, Inc.
# 14. Making the Body Beautiful
# 15. Jakob Der Luegner
# 16. The Call of Earth (Homecoming Saga, Vol 2)
# 17. Kingdom Come (TM)
# 18. Achilles' Choice
# 19. Texas Real Estate (Texas Real Estate)
# 20. Scribbles from the Same Island
# 21. Una Pena Observada
# 22. Love By Degree (Harlequin Romance, No. 2835)
# 23. The Jewish Community in Poland: Historical Essays
# 24. PRACTICAL MAGIC
# 25. The BFG (Puffin Fiction)
# 26. Purity Reigns (Laurel Shadrach Series, 1)
# 27. Fugitive Bride (The Australians) (Harlequin Presents, No. 2212)
# 28. No Llores Mas
# 29. Your's Till Niagara Falls, Abby
# 30. The Sign of the Twisted Candles (Nancy Drew Mystery Stories, No 9)

# %%
import pickle

# %%
with  open('/content/drive/MyDrive/Colab Notebooks/Book Recommendation System/model_svd.pkl', 'wb') as model_file:
  pickle.dump(model_svd, model_file)

# %%
with  open('/content/drive/MyDrive/Colab Notebooks/Book Recommendation System/model_nmf.pkl', 'wb') as model_file:
  pickle.dump(model_nmf, model_file)

# %%
# Load the model from the file
with open('/content/drive/MyDrive/Colab Notebooks/Book Recommendation System/model_svd.pkl', 'rb') as model_file:
    loaded_algo = pickle.load(model_file)

# %%
def get_top_n_recommendations_loaded(user_id, n=5):
  user_books = Ratings[Ratings['User-ID'] == user_id]['ISBN'].unique()
  all_books = Ratings['ISBN'].unique()
  books_to_predict = list(set(all_books) - set(user_books))

  user_books_str = [str(element) for element in user_books]
  a = (Books[Books['ISBN'].isin(user_books_str)][['Book-Title', 'Book-Author', 'Year-Of-Publication', 'Image-URL-L']])


  user_book_pairs = [(user_id, book_id, 0) for book_id in books_to_predict]
  predictions_cf = loaded_algo.test(user_book_pairs)

  top_n_recommendations = sorted(predictions_cf, key = lambda x: x.est, reverse = True)[:n]

  top_n_book_ids = [str(pred.iid) for pred in top_n_recommendations]

  top_n_book_ids_str = [str(element) for element in top_n_book_ids]
  b = (Books[Books['ISBN'].isin(top_n_book_ids_str)][['Book-Title', 'Book-Author', 'Year-Of-Publication', 'Image-URL-L']])

  return a, b

# %%
user_id = 276747

a, b = get_top_n_recommendations_loaded(user_id , 10)


a
# Out:
#                                Book-Title       Book-Author  \
# 1836                    Waiting to Exhale    Terry McMillan
# 4779             Little Altars Everywhere     Rebecca Wells
# 6276    Birdsong: A Novel of Love and War  Sebastian Faulks
# 246840  How to Deal With Difficult People     Rick Brinkman
# 246841      The Golden Rule of Schmoozing          Aye Jaye
#
#        Year-Of-Publication                                        Image-URL-L
# 1836                  1995  http://images.amazon.com/images/P/0671537458.0...
# 4779                  2003  http://images.amazon.com/images/P/0060517794.0...
# 6276                  1997  http://images.amazon.com/images/P/0679776818.0...
# 246840                1995  http://images.amazon.com/images/P/0943066433.0...
# 246841                1998  http://images.amazon.com/images/P/1885408226.0...

# %%
b
# Out:
#                                               Book-Title      Book-Author  \
# 915                   The Giver (21st Century Reference)       LOIS LOWRY
# 1057   Anne of Green Gables (Anne of Green Gables Nov...  L.M. MONTGOMERY
# 1571   The Fellowship of the Ring (The Lord of the Ri...   J.R.R. TOLKIEN
# 1985                                 The Handmaid's Tale  Margaret Atwood
# 4206   The Return of the King (The Lord of the Rings,...   J.R.R. TOLKIEN
# 5431        Harry Potter and the Goblet of Fire (Book 4)    J. K. Rowling
# 5506   Harry Potter and the Order of the Phoenix (Boo...    J. K. Rowling
# 6330   Harry Potter and the Prisoner of Azkaban (Book 3)    J. K. Rowling
# 8237                         Dune (Remembering Tomorrow)    Frank Herbert
# 19640  Griffin &amp; Sabine: An Extraordinary Corresp...     Nick Bantock
#
#       Year-Of-Publication                                        Image-URL-L
# 915                  1994  http://images.amazon.com/images/P/0440219078.0...
# 1057                 1982  http://images.amazon.com/images/P/055321313X.0...
# 1571                 1986  http://images.amazon.com/images/P/0345339703.0...
# 1985                 1989  http://images.amazon.com/images/P/0449212602.0...
# 4206                 1986  http://images.amazon.com/images/P/0345339738.0...
# 5431                 2000  http://images.amazon.com/images/P/0439139597.0...
# 5506                 2003  http://images.amazon.com/images/P/043935806X.0...
# 6330                 2001  http://images.amazon.com/images/P/0439136369.0...
# 8237                 1996  http://images.amazon.com/images/P/0441172717.0...
# 19640                1991  http://images.amazon.com/images/P/0877017883.0...
